# %%
#파이썬 유니코드

text="파이썬"
print(text)
# Out:
# 파이썬

# %%
encoded = text.encode("utf-8")
print(encoded)

print(type(encoded))
# Out:
# b'\xed\x8c\x8c\xec\x9d\xb4\xec\x8d\xac'
# <class 'bytes'>

# %%
decoded = encoded.decode("utf-8")

print(decoded)

print(type(decoded))
# Out:
# 파이썬
# <class 'str'>
